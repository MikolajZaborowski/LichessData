# %%
token = "" # here should be lichess API token, but i will hide my token because its confidential data

# %%
import pandas as pd
import numpy as np
import berserk
import json

# %%
session = berserk.TokenSession(token)
client = berserk.Client(session=session)

# %%
duno = client.games.export_by_player('EvilSaintPL') # posible adding max=300, because without limit it takes some time

# %%
# with open('data.json', 'w', encoding='utf-8') as f:
#     json.dump(list(duno), f, ensure_ascii=False, default=str) # saving data without any changes
# some_chess_data = pd.read_json('data.json')
# some_chess_data[:1] 
# im not gonna work on it, instead i will handle data without json.dump() to train working on dicts and list

# %%
ranking_data = client.users.get_rating_history('EvilSaintPL')

# %%
df1 = pd.read_json(json.dumps(list(duno), default=str))
df = df1.copy()

# %%
df = df1.copy()

# %%
df.head(1)
# at this point im looing into data, and deciding what data do i need"
# in this case i dont need moves, only a amount of moves played by side
# also its not important if was a game played in tourament
# days per turn have value only for corespondic chess games so i can drop it too
# swiss and initialFen also are not important
# from players -> user i need only one result, so i will take name + will add ranking points to players
# ratingDiff will be calculated later on my own
# Out:
#          id  rated   variant  speed   perf                         createdAt  \
# 0  uxE9ud30   True  standard  blitz  blitz  2023-06-01 16:22:19.034000+00:00
#
#                          lastMoveAt  status  \
# 0  2023-06-01 16:26:26.523000+00:00  resign
#
#                                              players winner  \
# 0  {'white': {'user': {'name': 'zajc1', 'id': 'za...  black
#
#                                                moves  \
# 0  e4 e5 d3 Nc6 Be3 d5 exd5 Qxd5 Nc3 Bb4 Ne2 Bg4 ...
#
#                                                clock tournament initialFen  \
# 0  {'initial': 300, 'increment': 0, 'totalTime': ...        NaN        NaN
#
#   swiss  daysPerTurn
# 0   NaN          NaN

# %% [markdown]
# # dealing with moves, tournament and players columns

# %%
df.moves = df["moves"].str.count(" ")//2 # changing moves column to numer of moves instead of notation
df.drop("tournament", axis=1, inplace=True) # droping unnessesary column
df.drop("initialFen", axis=1, inplace=True)
df.drop("swiss", axis=1, inplace=True)
df.drop("daysPerTurn", axis=1, inplace=True)

# %%
df.iloc[0,7]
# Out:
# 'mate'

# %%
def player(x: dict):
    if ('white' in x.keys()) & ('black' in x.keys()):
        if ("user" in x["white"].keys()) & ("user" in x["black"].keys()):
            plyer_data = {
                "white_player_name" : x['white']['user']['name'],
                "white_ranking" : x['white']['rating'],
                "black_player_name" : x['black']['user']['name'],
                "black_ranking" : x['black']['rating']
            }
        elif ("user" in x["white"].keys()):
            plyer_data = {
                "white_player_name" : x['white']['user']['name'],
                "white_ranking" : x['white']['rating'],
               "black_player_name" : "unknown",
                "black_ranking" : 0
            }
        elif ("user" in x["black"].keys()):
            plyer_data = {
                "black_player_name" : x['black']['user']['name'],
                "black_ranking" : x['black']['rating'],
                "white_player_name" : "unknown",
                "white_ranking" : 0
            }
    else:
        plyer_data = {"white_player_name":"unknown","white_ranking":0,"black_player_name":unknown,"black_ranking":0}
    result = pd.DataFrame(plyer_data, index=[0])
    return result

# %%
df.iloc[0,7]
# Out:
# 'mate'

# %%
c = ["white_player_name","white_ranking","black_player_name","black_ranking"]
finit = df["players"].apply(player)
result=pd.DataFrame(columns=c)
for i in range(len(finit)):
    result = pd.concat([result, finit[i]])
result =result.reset_index().drop("index", axis=1)
df = pd.concat([df, result], axis=1)  # adding separated players columns 
df.drop("players", axis=1, inplace=True) # droping players column

# %%
df.head(2)
# Out:
#          id  rated   variant  speed   perf                         createdAt  \
# 0  nSkSOyKk   True  standard  blitz  blitz  2023-06-01 14:44:58.061000+00:00
# 1  ypRGupyw   True  standard  blitz  blitz  2023-06-01 01:37:21.296000+00:00
#
#                          lastMoveAt     status winner  moves  \
# 0  2023-06-01 14:50:56.745000+00:00       mate  white     30
# 1  2023-06-01 01:47:18.336000+00:00  outoftime  black     36
#
#                                                clock initialFen swiss  \
# 0  {'initial': 300, 'increment': 0, 'totalTime': ...        NaN   NaN
# 1  {'initial': 300, 'increment': 0, 'totalTime': ...        NaN   NaN
#
#    daysPerTurn white_player_name white_ranking black_player_name black_ranking
# 0          NaN       EvilSaintPL          1763          Oncedead          1742
# 1          NaN            Jorjao          1687       EvilSaintPL          1758

# %% [markdown]
# # dealing with clock and perf column

# %%
df.iloc[0,10]
# Out:
# {'initial': 300, 'increment': 0, 'totalTime': 300}

# %%
def clock(x):
    print(x)
    if 'initial' in x.keys():
        return x["initial"]
     
        print(x)
        return 0

# %%
df["clock"]=df["clock"].apply(clock)
# Out:
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 240, 'increment': 0, 'totalTime': 240}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 600, 'increment': 0, 'totalTime': 600}
# {'initial': 600, 'increment': 0, 'totalTime': 600}
# {'initial': 1800, 'increment': 0, 'totalTime': 1800}
# {'initial': 1800, 'increment': 0, 'totalTime': 1800}
# {'initial': 1800, 'increment': 0, 'totalTime': 1800}
# {'initial': 90, 'increment': 0, 'totalTime': 90}
# {'initial': 90, 'increment': 0, 'totalTime': 90}
# {'initial': 90, 'increment': 0, 'totalTime': 90}
# {'initial': 90, 'increment': 0, 'totalTime': 90}
# {'initial': 90, 'increment': 0, 'totalTime': 90}
# {'initial': 90, 'increment': 0, 'totalTime': 90}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 60, 'increment': 1, 'totalTime': 100}
# {'initial': 60, 'increment': 1, 'totalTime': 100}
# {'initial': 60, 'increment': 1, 'totalTime': 100}
# {'initial': 60, 'increment': 1, 'totalTime': 100}
# {'initial': 60, 'increment': 1, 'totalTime': 100}
# {'initial': 60, 'increment': 1, 'totalTime': 100}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 60, 'increment': 1, 'totalTime': 100}
# {'initial': 60, 'increment': 1, 'totalTime': 100}
# {'initial': 180, 'increment': 1, 'totalTime': 220}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 1, 'totalTime': 220}
# {'initial': 180, 'increment': 1, 'totalTime': 220}
# {'initial': 180, 'increment': 1, 'totalTime': 220}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 180, 'increment': 2, 'totalTime': 260}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 90, 'increment': 1, 'totalTime': 130}
# {'initial': 90, 'increment': 1, 'totalTime': 130}
# {'initial': 90, 'increment': 1, 'totalTime': 130}
# {'initial': 90, 'increment': 1, 'totalTime': 130}
# {'initial': 90, 'increment': 1, 'totalTime': 130}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 120, 'increment': 1, 'totalTime': 160}
# {'initial': 120, 'increment': 0, 'totalTime': 120}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 90, 'increment': 8, 'totalTime': 410}
# {'initial': 90, 'increment': 8, 'totalTime': 410}
# {'initial': 90, 'increment': 8, 'totalTime': 410}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 900, 'increment': 8, 'totalTime': 1220}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 600, 'increment': 0, 'totalTime': 600}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 600, 'increment': 0, 'totalTime': 600}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 2, 'totalTime': 140}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 1, 'totalTime': 340}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 60, 'increment': 0, 'totalTime': 60}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 5, 'totalTime': 500}
# {'initial': 300, 'increment': 5, 'totalTime': 500}
# {'initial': 300, 'increment': 5, 'totalTime': 500}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 1800, 'increment': 10, 'totalTime': 2200}
# {'initial': 1800, 'increment': 16, 'totalTime': 2440}
# {'initial': 300, 'increment': 2, 'totalTime': 380}
# {'initial': 300, 'increment': 2, 'totalTime': 380}
# {'initial': 600, 'increment': 0, 'totalTime': 600}
# {'initial': 600, 'increment': 0, 'totalTime': 600}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 300, 'increment': 0, 'totalTime': 300}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# {'initial': 180, 'increment': 0, 'totalTime': 180}
# nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df["clock"]=df["clock"].apply(clock)
#
# File D:\Lichess_Project\venv\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File D:\Lichess_Project\venv\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File D:\Lichess_Project\venv\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File D:\Lichess_Project\venv\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[21], line 3, in clock(x)
#       1 def clock(x):
#       2     print(x)
# ----> 3     if 'initial' in x.keys():
#       4         return x["initial"]
#       5     else:
#
# AttributeError: 'float' object has no attribute 'keys'

# %% [markdown]
# # deling with time columns

# %%
df["createdAt"] = df["createdAt"].apply(lambda x: pd.to_datetime(x).tz_convert('Europe/Berlin'))
df["lastMoveAt"] = df["lastMoveAt"].apply(lambda x: pd.to_datetime(x).tz_convert('Europe/Berlin'))

# %%
df.head(2)

# %% [markdown]
# # Changing to valueable data   - OLD METHOD

# %%
#games = list(duno)

# %%
# cols= ['id', 'rated', 'variant', 'speed', 'createdAt', 'lastmoveAt', 'status',
#        'winner', 'clock', 'increment', 'white_player', 'white_rating',
#        'black_player', 'black_rating', 'ratingDiff']
# chessdata = pd.DataFrame(columns=cols)

# for i in range(len(games)):
#     if i%100==0:
#         print(i)
#     df = pd.DataFrame.from_dict(games[i])
#     if (df.loc["white","speed"]!="correspondence") & ('user' in df.loc["black","players"].keys()) & ('user' in df.loc["white","players"].keys()):
#         if (df.loc["white", "status"]!="draw") & (df.loc["white", "status"]!="stalemate") & (df.loc["white", "status"]!="outoftime") & (df.loc["white", "status"]!="timeout"):
#             d = {
#             "id" : df.loc["white", "id"],
#             "rated": df.loc["white", "rated"],
#             "variant": df.loc["white", "variant"],
#             "speed": df.loc["white", "speed"],
#             "createdAt": df.loc["white", "createdAt"],
#             "lastmoveAt": df.loc["white", "lastMoveAt"],
#             "status": df.loc["white", "status"],
#             "winner": df.loc["white", "winner"],
#             "clock": df.loc["initial","clock"],
#             "increment": df.loc["increment","clock"],
#             "white_player": df.loc["white","players" ]["user"]["name"],
#             "white_rating": df.loc["white","players" ]['rating'],
#             "black_player": df.loc["black","players" ]["user"]["name"],
#             "black_rating": df.loc["black","players" ]['rating'],
#             }
#             d = pd.Series(d)
#             d = pd.DataFrame(data=d)
#             d = d.transpose()
#             chessdata = pd.concat([chessdata, d])
#         else:
#             d = {
#             "id" : df.loc["white", "id"],
#             "rated": df.loc["white", "rated"],
#             "variant": df.loc["white", "variant"],
#             "speed": df.loc["white", "speed"],
#             "createdAt": df.loc["white", "createdAt"],
#             "lastmoveAt": df.loc["white", "lastMoveAt"],
#             "status": df.loc["white", "status"],
#             "winner": 0,
#             "clock": df.loc["initial","clock"],
#             "increment": df.loc["increment","clock"],
#             "white_player": df.loc["white","players" ]["user"]["name"],
#             "white_rating": df.loc["white","players" ]['rating'],
#             "black_player": df.loc["black","players" ]["user"]["name"],
#             "black_rating": df.loc["black","players" ]['rating'],
#             }
#             d = pd.Series(d)
#             d = pd.DataFrame(data=d)
#             d = d.transpose()
#             chessdata = pd.concat([chessdata, d])

# %%
# chessdata=chessdata.reset_index()
# chessdata.drop("index",axis=1,inplace=True)

# %%
# chessdata.shape

# %%
# chessdata
